# %%
import os
import re
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

os.chdir('C:/Users/cg08900/Documents/Pandora/Personale/kaggle/NCAA_2k19/prog/functions/')

from ncaa19 import *

sns.set()

# %%
PATH_DATASETS = 'C:/Users/cg08900/Documents/Pandora/Personale/kaggle/NCAA_2k19/datasets/'
PATH_OUTPUT = 'C:/Users/cg08900/Documents/Pandora/Personale/kaggle/NCAA_2k19/datasets/'
PATH_ELAB = 'C:/Users/cg08900/Documents/Pandora/Personale/kaggle/NCAA_2k19/elaborazioni/'

REGRESSORS  = ['delta_poss_m', 'delta_opp_poss_m',
              'delta_ass_ratio', 'delta_tov_ratio',
              'delta_reb_rate', 'delta_opp_true_fg_pct',
              'delta_off_rating_m', 'delta_def_rating_m',
              'delta_net_rating_m', 'delta_pace_m',
              'delta_off_rating_m_last30D', 'delta_def_rating_m_last30D',
              'delta_net_rating_m_last30D', 'delta_off_rating_m_vs_topseeds',
              'delta_def_rating_m_vs_topseeds', 'delta_net_rating_m_vs_topseeds',
              'delta_c_N_season', 'delta_w_pct', 
              'delta_w_pct_last30D', 'delta_w_pct_vs_topseeds',
              'delta_c_W_PCT_allT', 'delta_c_W_PCT_vs_topseeds_allT',
              'delta_MOR', 'delta_POM',
              'delta_SAG']

df_features_all = pd.read_csv(PATH_OUTPUT + '03Py_NCAA_dataset_con_indicatori.csv',
                              sep='|')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.isotonic import IsotonicRegression

def ir_fit(var_series, target_series):
  ir = IsotonicRegression(increasing="auto")
  ir.fit(var_series, target_series)
  return(ir)

def ir_apply(ir, var_series):
  return(pd.Series(ir.predict(var_series), index = var_series.index))

def ir_plot(var_base, var_iso, var_target, n_classes = 10):
  cl_x = pd.qcut(var_base, n_classes, labels = False, duplicates = 'drop')
  stats_td = var_target.groupby(cl_x).mean()
  stats_iso = var_iso.groupby(cl_x).mean()
  # plot figure
  fig = plt.figure()
  ax = fig.add_subplot(111)
  ax.plot(stats_td, 'bs-')
  ax.plot(stats_iso, 'rs-')
  ax.yaxis.grid(True, linestyle='--', linewidth=1)
  ax.xaxis.set_label_text("Percentili variabile X")
  ax.yaxis.set_label_text("Td")
  plt.show()

filter_train = (df_features_all['Season']>=2008) & (df_features_all['Season']<=2014)
filter_test = (df_features_all['Season'].isin([2015, 2016, 2017, 2018]))
df_train = df_features_all.loc[filter_train, :].copy()
df_test = df_features_all.loc[filter_test, :].copy()
df_train.fillna(0, inplace=True) # is it right... @Stefano
df_test.fillna(0, inplace=True)

# %%
df_train.columns
# Out:
# Index(['Season', 'DayNum', 'TeamID', 'TeamID_opp', 'Score_left', 'Score_right',
#        'win_dummy', 'delta', 'NumOT', 'delta_poss_m', 'delta_opp_poss_m',
#        'delta_ass_ratio', 'delta_tov_ratio', 'delta_reb_rate',
#        'delta_opp_true_fg_pct', 'delta_off_rating_m', 'delta_def_rating_m',
#        'delta_net_rating_m', 'delta_pace_m', 'delta_off_rating_m_last30D',
#        'delta_def_rating_m_last30D', 'delta_net_rating_m_last30D',
#        'delta_off_rating_m_vs_topseeds', 'delta_def_rating_m_vs_topseeds',
#        'delta_net_rating_m_vs_topseeds', 'delta_w_pct', 'delta_w_pct_last30D',
#        'delta_w_pct_vs_topseeds', 'delta_c_N_season', 'delta_c_N_champ_W',
#        'delta_c_W_PCT_allT', 'delta_c_W_PCT_vs_topseeds_allT', 'delta_MOR',
#        'delta_POM', 'delta_SAG'],
#       dtype='object')

# %%
# apply isotonic transformation
for regressor in REGRESSORS:

    print("Transform feature {0}".format(regressor))

    ir_var = ir_fit(df_train[regressor], df_train['win_dummy'])
    df_train['piso_' + regressor] =\
      ir_apply(ir_var, df_train[regressor])
    df_test['piso_' + regressor] =\
      ir_apply(ir_var, df_test[regressor])

    ir_plot(df_test[regressor],
            df_test['piso_' + regressor],
            df_test['win_dummy'], 25)
# Out:
# Transform feature delta_poss_m
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_opp_poss_m
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_ass_ratio
# Transform feature delta_tov_ratio
# Transform feature delta_reb_rate
# Transform feature delta_opp_true_fg_pct
# Transform feature delta_off_rating_m
# Transform feature delta_def_rating_m
# Transform feature delta_net_rating_m
# Transform feature delta_pace_m
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_off_rating_m_last30D
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_def_rating_m_last30D
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_net_rating_m_last30D
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_off_rating_m_vs_topseeds
# Transform feature delta_def_rating_m_vs_topseeds
# Transform feature delta_net_rating_m_vs_topseeds
# Transform feature delta_c_N_season
# Transform feature delta_w_pct
# Transform feature delta_w_pct_last30D
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_w_pct_vs_topseeds
# Transform feature delta_c_W_PCT_allT
# Transform feature delta_c_W_PCT_vs_topseeds_allT
# Transform feature delta_MOR
# Transform feature delta_POM
# Transform feature delta_SAG

# %%
import numpy as np
from itertools import chain

def logloss(y_hat, p_1win):
    n = len(y_hat)
    logloss = (-1/n) * sum((y_hat * np.log(p_1win)) + (1 - y_hat) * np.log(1 - p_1win))
    return(logloss)

def logistic(df_tr, features, target, df_valid=None, penalty='l2', C=1.0):
    X = df_tr.loc[:, features]
    y = df_tr.loc[:, target]
    sk_model = LogisticRegression(fit_intercept=True, penalty=penalty, C=C)\
        .fit(X, y)
    df_results = pd.DataFrame({'feature': ["(Intercept)"] + features,
                               'beta': sk_model.intercept_.tolist() + sk_model.coef_[0].tolist()})
    print(df_results)
    if df_valid is not None:
        X_valid = df_valid.loc[:, features]
        y_valid = df_valid.loc[:, target]
        X_valid.fillna(0, inplace=True) # TODO: ask Stefano!
        p_valid = pd.Series(sk_model.predict_proba(X_valid)[:,1], index = y_valid.index)
        p_valid[p_valid >= 0.975] = 0.975
        p_valid[p_valid <= 0.025] = 0.025
        print(max(p_valid))
        print(min(p_valid))
        print("Log loss for test: {0}".format(logloss(y_valid, p_valid)))

    return None

logistic(df_train, REGRESSORS,
         'win_dummy', df_test, penalty='l1', C=0.50)

# -.10 log loss... yet still very high!
logistic(df_train, ['piso_' + r for r in REGRESSORS],
         'win_dummy', df_test, penalty='l1', C=0.50)
# Out:
#                            feature      beta
# 0                      (Intercept)  0.044906
# 1                     delta_poss_m  0.000000
# 2                 delta_opp_poss_m -0.012862
# 3                  delta_ass_ratio -0.162684
# 4                  delta_tov_ratio -0.013152
# 5                   delta_reb_rate  0.469356
# 6            delta_opp_true_fg_pct  0.094271
# 7               delta_off_rating_m  0.000000
# 8               delta_def_rating_m -0.004293
# 9               delta_net_rating_m  0.137650
# 10                    delta_pace_m  0.000000
# 11      delta_off_rating_m_last30D -0.018213
# 12      delta_def_rating_m_last30D  0.000000
# 13      delta_net_rating_m_last30D -0.061863
# 14  delta_off_rating_m_vs_topseeds  0.000000
# 15  delta_def_rating_m_vs_topseeds -0.015965
# 16  delta_net_rating_m_vs_topseeds  0.002847
# 17                delta_c_N_season -0.068525
# 18                     delta_w_pct  0.000000
# 19             delta_w_pct_last30D  1.841784
# 20         delta_w_pct_vs_topseeds  0.000000
# 21              delta_c_W_PCT_allT  0.000000
# 22  delta_c_W_PCT_vs_topseeds_allT  0.000000
# 23                       delta_MOR -0.034447
# 24                       delta_POM  0.021582
# 25                       delta_SAG -0.001144
# 0.975
# 0.025
# Log loss for test: 0.5939137006184553
#                                 feature      beta
# 0                           (Intercept) -3.330367
# 1                     piso_delta_poss_m  0.000000
# 2                 piso_delta_opp_poss_m  0.000000
# 3                  piso_delta_ass_ratio  0.000000
# 4                  piso_delta_tov_ratio  0.000000
# 5                   piso_delta_reb_rate  0.623384
# 6            piso_delta_opp_true_fg_pct  0.000000
# 7               piso_delta_off_rating_m  0.000000
# 8               piso_delta_def_rating_m  0.000000
# 9               piso_delta_net_rating_m  0.473373
# 10                    piso_delta_pace_m  0.000000
# 11      piso_delta_off_rating_m_last30D  0.000000
# 12      piso_delta_def_rating_m_last30D  0.000000
# 13      piso_delta_net_rating_m_last30D  0.000000
# 14  piso_delta_off_rating_m_vs_topseeds  0.000000
# 15  piso_delta_def_rating_m_vs_topseeds  0.432373
# 16  piso_delta_net_rating_m_vs_topseeds  0.000000
# 17                piso_delta_c_N_season  0.000000
# 18                     piso_delta_w_pct  0.966646
# 19             piso_delta_w_pct_last30D  0.000000
# 20         piso_delta_w_pct_vs_topseeds  0.000000
# 21              piso_delta_c_W_PCT_allT  0.691116
# 22  piso_delta_c_W_PCT_vs_topseeds_allT  0.299563
# 23                       piso_delta_MOR  2.671573
# 24                       piso_delta_POM  0.548604
# 25                       piso_delta_SAG  0.081906
# 0.9531100628667563
# 0.046207245954627996
# Log loss for test: 0.5621276024908813

# %%
def logloss(y_hat, p_1win):
    n = len(y_hat)
    logloss = (-1) * (y_hat * np.log(p_1win)) + (1 - y_hat) * np.log(1 - p_1win)
    return(logloss)

def logistic(df_tr, features, target, df_valid=None, penalty='l2', C=1.0):
    X = df_tr.loc[:, features]
    y = df_tr.loc[:, target]
    sk_model = LogisticRegression(fit_intercept=True, penalty=penalty, C=C)\
        .fit(X, y)
    df_results = pd.DataFrame({'feature': ["(Intercept)"] + features,
                               'beta': sk_model.intercept_.tolist() + sk_model.coef_[0].tolist()})
    print(df_results)
    if df_valid is not None:
        X_valid = df_valid.loc[:, features]
        y_valid = df_valid.loc[:, target]
        X_valid.fillna(0, inplace=True) # TODO: ask Stefano!
        p_valid = pd.Series(sk_model.predict_proba(X_valid)[:,1], index = y_valid.index)
        # p_valid[p_valid >= 0.97] = 0.97
        # p_valid[p_valid <= 0.03] = 0.03
        
        out = df_valid
        out['win_pr'] = p_valid
        out['logloss'] = logloss(y_valid, p_valid)
    return out

df_valid_out = logistic(df_train, ['piso_' + r for r in REGRESSORS],
                        'win_dummy', df_test, penalty='l1', C=0.50)
# Out:
#                                 feature      beta
# 0                           (Intercept) -3.330369
# 1                     piso_delta_poss_m  0.000000
# 2                 piso_delta_opp_poss_m  0.000000
# 3                  piso_delta_ass_ratio  0.000000
# 4                  piso_delta_tov_ratio  0.000000
# 5                   piso_delta_reb_rate  0.623692
# 6            piso_delta_opp_true_fg_pct  0.000000
# 7               piso_delta_off_rating_m  0.000000
# 8               piso_delta_def_rating_m  0.000000
# 9               piso_delta_net_rating_m  0.472572
# 10                    piso_delta_pace_m  0.000000
# 11      piso_delta_off_rating_m_last30D  0.000000
# 12      piso_delta_def_rating_m_last30D  0.000000
# 13      piso_delta_net_rating_m_last30D  0.000000
# 14  piso_delta_off_rating_m_vs_topseeds  0.000000
# 15  piso_delta_def_rating_m_vs_topseeds  0.432598
# 16  piso_delta_net_rating_m_vs_topseeds  0.000000
# 17                piso_delta_c_N_season  0.000000
# 18                     piso_delta_w_pct  0.966719
# 19             piso_delta_w_pct_last30D  0.000000
# 20         piso_delta_w_pct_vs_topseeds  0.000000
# 21              piso_delta_c_W_PCT_allT  0.690965
# 22  piso_delta_c_W_PCT_vs_topseeds_allT  0.299825
# 23                       piso_delta_MOR  2.669409
# 24                       piso_delta_POM  0.549369
# 25                       piso_delta_SAG  0.083335

# %%
df_valid_out.to_excel(PATH_DATASETS + "07Py_NCAA_valid_output.xlsx")

# %%
# Out:
# Transform feature delta_poss_m
# Transform feature delta_opp_poss_m
# Transform feature delta_ass_ratio
# Transform feature delta_tov_ratio
# Transform feature delta_reb_rate
# Transform feature delta_opp_true_fg_pct
# Transform feature delta_off_rating_m
# Transform feature delta_def_rating_m
# Transform feature delta_net_rating_m
# Transform feature delta_pace_m
# Transform feature delta_off_rating_m_last30D
# Transform feature delta_def_rating_m_last30D
# Transform feature delta_net_rating_m_last30D
# Transform feature delta_off_rating_m_vs_topseeds
# Transform feature delta_def_rating_m_vs_topseeds
# Transform feature delta_net_rating_m_vs_topseeds
# Transform feature delta_c_N_season
# Transform feature delta_w_pct
# Transform feature delta_w_pct_last30D
# Transform feature delta_w_pct_vs_topseeds
# Transform feature delta_c_W_PCT_allT
# Transform feature delta_c_W_PCT_vs_topseeds_allT
# Transform feature delta_MOR
# Transform feature delta_POM
# Transform feature delta_SAG
# testing on: 2015
#                                 feature      beta
# 0                           (Intercept) -3.331800
# 1                     piso_delta_poss_m  0.000000
# 2                 piso_delta_opp_poss_m  0.000000
# 3                  piso_delta_ass_ratio  0.000000
# 4                  piso_delta_tov_ratio  0.000000
# 5                   piso_delta_reb_rate  0.624959
# 6            piso_delta_opp_true_fg_pct  0.000000
# 7               piso_delta_off_rating_m  0.000000
# 8               piso_delta_def_rating_m  0.000000
# 9               piso_delta_net_rating_m  0.474002
# 10                    piso_delta_pace_m  0.000000
# 11      piso_delta_off_rating_m_last30D  0.000000
# 12      piso_delta_def_rating_m_last30D  0.000000
# 13      piso_delta_net_rating_m_last30D  0.000000
# 14  piso_delta_off_rating_m_vs_topseeds  0.000000
# 15  piso_delta_def_rating_m_vs_topseeds  0.433118
# 16  piso_delta_net_rating_m_vs_topseeds  0.000000
# 17                piso_delta_c_N_season  0.000000
# 18                     piso_delta_w_pct  0.966169
# 19             piso_delta_w_pct_last30D  0.000000
# 20         piso_delta_w_pct_vs_topseeds  0.000000
# 21              piso_delta_c_W_PCT_allT  0.691886
# 22  piso_delta_c_W_PCT_vs_topseeds_allT  0.298904
# 23                       piso_delta_MOR  2.675471
# 24                       piso_delta_POM  0.539073
# 25                       piso_delta_SAG  0.087620
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_poss_m
# Transform feature delta_opp_poss_m
# Transform feature delta_ass_ratio
# Transform feature delta_tov_ratio
# Transform feature delta_reb_rate
# Transform feature delta_opp_true_fg_pct
# Transform feature delta_off_rating_m
# Transform feature delta_def_rating_m
# Transform feature delta_net_rating_m
# Transform feature delta_pace_m
# Transform feature delta_off_rating_m_last30D
# Transform feature delta_def_rating_m_last30D
# Transform feature delta_net_rating_m_last30D
# Transform feature delta_off_rating_m_vs_topseeds
# Transform feature delta_def_rating_m_vs_topseeds
# Transform feature delta_net_rating_m_vs_topseeds
# Transform feature delta_c_N_season
# Transform feature delta_w_pct
# Transform feature delta_w_pct_last30D
# Transform feature delta_w_pct_vs_topseeds
# Transform feature delta_c_W_PCT_allT
# Transform feature delta_c_W_PCT_vs_topseeds_allT
# Transform feature delta_MOR
# Transform feature delta_POM
# Transform feature delta_SAG
# testing on: 2016
#                                 feature      beta
# 0                           (Intercept) -3.180143
# 1                     piso_delta_poss_m  0.000000
# 2                 piso_delta_opp_poss_m  0.000000
# 3                  piso_delta_ass_ratio  0.000000
# 4                  piso_delta_tov_ratio  0.000000
# 5                   piso_delta_reb_rate  0.540408
# 6            piso_delta_opp_true_fg_pct  0.000000
# 7               piso_delta_off_rating_m  0.000000
# 8               piso_delta_def_rating_m  0.000000
# 9               piso_delta_net_rating_m  1.290034
# 10                    piso_delta_pace_m  0.000000
# 11      piso_delta_off_rating_m_last30D  0.000000
# 12      piso_delta_def_rating_m_last30D  0.000000
# 13      piso_delta_net_rating_m_last30D  0.000000
# 14  piso_delta_off_rating_m_vs_topseeds  0.000000
# 15  piso_delta_def_rating_m_vs_topseeds  0.000000
# 16  piso_delta_net_rating_m_vs_topseeds  0.000000
# 17                piso_delta_c_N_season  0.000000
# 18                     piso_delta_w_pct  0.404198
# 19             piso_delta_w_pct_last30D  0.000000
# 20         piso_delta_w_pct_vs_topseeds  0.000000
# 21              piso_delta_c_W_PCT_allT  0.000000
# 22  piso_delta_c_W_PCT_vs_topseeds_allT  1.551541
# 23                       piso_delta_MOR  2.143832
# 24                       piso_delta_POM  0.088857
# 25                       piso_delta_SAG  0.434079
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_poss_m
# Transform feature delta_opp_poss_m
# Transform feature delta_ass_ratio
# Transform feature delta_tov_ratio
# Transform feature delta_reb_rate
# Transform feature delta_opp_true_fg_pct
# Transform feature delta_off_rating_m
# Transform feature delta_def_rating_m
# Transform feature delta_net_rating_m
# Transform feature delta_pace_m
# Transform feature delta_off_rating_m_last30D
# Transform feature delta_def_rating_m_last30D
# Transform feature delta_net_rating_m_last30D
# Transform feature delta_off_rating_m_vs_topseeds
# Transform feature delta_def_rating_m_vs_topseeds
# Transform feature delta_net_rating_m_vs_topseeds
# Transform feature delta_c_N_season
# Transform feature delta_w_pct
# Transform feature delta_w_pct_last30D
# Transform feature delta_w_pct_vs_topseeds
# Transform feature delta_c_W_PCT_allT
# Transform feature delta_c_W_PCT_vs_topseeds_allT
# Transform feature delta_MOR
# Transform feature delta_POM
# Transform feature delta_SAG
# testing on: 2017
#                                 feature      beta
# 0                           (Intercept) -3.031504
# 1                     piso_delta_poss_m  0.000000
# 2                 piso_delta_opp_poss_m  0.000000
# 3                  piso_delta_ass_ratio  0.000000
# 4                  piso_delta_tov_ratio  0.000000
# 5                   piso_delta_reb_rate  0.000000
# 6            piso_delta_opp_true_fg_pct  0.000000
# 7               piso_delta_off_rating_m  0.000000
# 8               piso_delta_def_rating_m  0.000000
# 9               piso_delta_net_rating_m  0.876562
# 10                    piso_delta_pace_m  0.000000
# 11      piso_delta_off_rating_m_last30D  0.000000
# 12      piso_delta_def_rating_m_last30D  0.000000
# 13      piso_delta_net_rating_m_last30D  0.000000
# 14  piso_delta_off_rating_m_vs_topseeds  0.000000
# 15  piso_delta_def_rating_m_vs_topseeds  0.000000
# 16  piso_delta_net_rating_m_vs_topseeds  0.000000
# 17                piso_delta_c_N_season  0.000000
# 18                     piso_delta_w_pct  0.556252
# 19             piso_delta_w_pct_last30D  0.000000
# 20         piso_delta_w_pct_vs_topseeds  0.000000
# 21              piso_delta_c_W_PCT_allT  0.329429
# 22  piso_delta_c_W_PCT_vs_topseeds_allT  1.462269
# 23                       piso_delta_MOR  1.865460
# 24                       piso_delta_POM  1.070826
# 25                       piso_delta_SAG  0.000000
# Transform feature delta_poss_m
# Transform feature delta_opp_poss_m
# Transform feature delta_ass_ratio
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Transform feature delta_tov_ratio
# Transform feature delta_reb_rate
# Transform feature delta_opp_true_fg_pct
# Transform feature delta_off_rating_m
# Transform feature delta_def_rating_m
# Transform feature delta_net_rating_m
# Transform feature delta_pace_m
# Transform feature delta_off_rating_m_last30D
# Transform feature delta_def_rating_m_last30D
# Transform feature delta_net_rating_m_last30D
# Transform feature delta_off_rating_m_vs_topseeds
# Transform feature delta_def_rating_m_vs_topseeds
# Transform feature delta_net_rating_m_vs_topseeds
# Transform feature delta_c_N_season
# Transform feature delta_w_pct
# Transform feature delta_w_pct_last30D
# Transform feature delta_w_pct_vs_topseeds
# Transform feature delta_c_W_PCT_allT
# Transform feature delta_c_W_PCT_vs_topseeds_allT
# Transform feature delta_MOR
# Transform feature delta_POM
# Transform feature delta_SAG
# testing on: 2018
#                                 feature      beta
# 0                           (Intercept) -3.360004
# 1                     piso_delta_poss_m  0.000000
# 2                 piso_delta_opp_poss_m  0.000000
# 3                  piso_delta_ass_ratio  0.000000
# 4                  piso_delta_tov_ratio  0.203986
# 5                   piso_delta_reb_rate  0.146488
# 6            piso_delta_opp_true_fg_pct  0.000000
# 7               piso_delta_off_rating_m  0.000000
# 8               piso_delta_def_rating_m  0.079311
# 9               piso_delta_net_rating_m  0.671224
# 10                    piso_delta_pace_m  0.000000
# 11      piso_delta_off_rating_m_last30D  0.000000
# 12      piso_delta_def_rating_m_last30D  0.000000
# 13      piso_delta_net_rating_m_last30D  0.000000
# 14  piso_delta_off_rating_m_vs_topseeds  0.000000
# 15  piso_delta_def_rating_m_vs_topseeds  0.406715
# 16  piso_delta_net_rating_m_vs_topseeds  0.000000
# 17                piso_delta_c_N_season  0.000000
# 18                     piso_delta_w_pct  0.667532
# 19             piso_delta_w_pct_last30D  0.000000
# 20         piso_delta_w_pct_vs_topseeds  0.000000
# 21              piso_delta_c_W_PCT_allT  0.000000
# 22  piso_delta_c_W_PCT_vs_topseeds_allT  1.755962
# 23                       piso_delta_MOR  2.229719
# 24                       piso_delta_POM  0.109533
# 25                       piso_delta_SAG  0.585192
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# C:\Users\cg08900\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\sklearn\isotonic.py:70: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
